# %%
from pokemon_find import pokemon_find
from word_count import word_count
import csv
import pandas as pd

c

# %%
print(len(pokemon_name_5))
a = 100
for name in pokemon_name_5:
    all_miss = pokemon_find(pokemon_name_5, "", name)
    if a >= len(all_miss):
        print(name)
        print(len(all_miss))
        a = len(all_miss)
# Out:
# 286
# リザードン
# 93
# キングラー
# 86
# サンダース
# 83
# ソーナンス
# 83
# ザングース
# 80
# ルナトーン
# 76
# ジーランス
# 72
# レントラー
# 68

# %%
print(len(pokemon_find(pokemon_name_5,"","ブラッキースカタンク")))
# Out:
# 33

# %%
ren = pokemon_find(pokemon_name_5, "レン", "ルナトーロズイド")
print(ren)
print(len(ren))
print(ren)
word_count(ren)
a=100
for name in pokemon_find(pokemon_name_5, "", "レン"):
    all_miss = pokemon_find(ren, "", name)
    if a >= len(all_miss):
        print(name)
        print(len(all_miss))
        a = len(all_miss)

# c_in = pokemon_find(pokemon_name_5, "", "ナ")
# for d in c_in:
#     if len(pokemon_find(ren, "", d)) <= 1:
#         print(d)
#         print(pokemon_find(ren, "", d))
# ['オニドリル', 'ゴルダック', 'オコリザル', 'レアコイル', 'ヨルノズク', 'マグカルゴ', 'ドクケイル', 'ヤルキモノ', 'チルタリス', 'ソルロック', 
#  'ユレイドル', 'レジスチル', 'モウカザル', 'ゴウカザル', 'ラムパルド', 'グレッグル', 'ジバコイル', 'エレキブル', 'エルレイド', 'ディアルガ', 'アルセウス']
# Out:
# ['レディアン', 'カクレオン']
# 2
# ['レディアン', 'カクレオン']
# ン    2
# レ    2
# ク    1
# ィ    1
# デ    1
# ア    1
# オ    1
# カ    1
# dtype: int64
# フシギダネ
# 2
# フシギソウ
# 2
# フシギバナ
# 2
# カメックス
# 1
# オニスズメ
# 1
# オニドリル
# 1
# アーボック
# 0
# アズマオウ
# 0
# ネイティオ
# 0
# ラティオス
# 0
# デオキシス
# 0
# ビクティニ
# 0

# %%
kame = pokemon_find(ren, "", "カイリキー")
a=100
for name in pokemon_find(pokemon_name_5, "", "ル"):
    all_miss = pokemon_find(kame, "", name)
    if a >= len(all_miss):
        print(name)
        print(len(all_miss))
        a = len(all_miss)
print(kame)
# Out:
# フシギダネ
# 7
# フシギソウ
# 6
# カメックス
# 2
# アーボック
# 2
# ストライク
# 2
# ヘラクロス
# 2
# サクラビス
# 2
# レックウザ
# 2
# ミノムッチ
# 2
# マスキッパ
# 2
# クレセリア
# 1
# ['ゴルダック', 'ヨルノズク', 'ソルロック', 'レジスチル', 'ラムパルド', 'グレッグル', 'ディアルガ', 'アルセウス']

# %%
azu = pokemon_find(kame, "", "")
a=100
for name in pokemon_find(pokemon_name_5, "", "ル"):
    all_miss = pokemon_find(azu, "", name)
    if a >= len(all_miss):
        print(name)
        print(len(all_miss))
        a = len(all_miss)
print(pokemon_find(azu,"",""))
print(azu)
# Out:
# フシギダネ
# 1
# フシギソウ
# 1
# フシギバナ
# 1
# リザードン
# 0
# ライチュウ
# 0
# サンドパン
# 0
# ニドラン♀
# 0
# ニドリーナ
# 0
# ニドクイン
# 0
# ニドラン♂
# 0
# ニドリーノ
# 0
# ニドキング
# 0
# ラフレシア
# 0
# パラセクト
# 0
# ユンゲラー
# 0
# メノクラゲ
# 0
# ドククラゲ
# 0
# ドードリオ
# 0
# スリーパー
# 0
# キングラー
# 0
# サワムラー
# 0
# エビワラー
# 0
# マタドガス
# 0
# モンジャラ
# 0
# バリヤード
# 0
# ストライク
# 0
# ギャラドス
# 0
# オムナイト
# 0
# オムスター
# 0
# メガニウム
# 0
# ヒノアラシ
# 0
# マグマラシ
# 0
# アリアドス
# 0
# ランターン
# 0
# ブラッキー
# 0
# ヤミカラス
# 0
# ヤドキング
# 0
# グライガー
# 0
# ヘラクロス
# 0
# デリバード
# 0
# エアームド
# 0
# キングドラ
# 0
# ドンファン
# 0
# カポエラー
# 0
# エレキッド
# 0
# ヨーギラス
# 0
# サナギラス
# 0
# バンギラス
# 0
# ラグラージ
# 0
# カラサリス
# 0
# ペリッパー
# 0
# ボスゴドラ
# 0
# チャーレム
# 0
# ナックラー
# 0
# ビブラーバ
# 0
# フライゴン
# 0
# ドジョッチ
# 0
# ユキワラシ
# 0
# タマザラシ
# 0
# トドグラー
# 0
# サクラビス
# 0
# ジーランス
# 0
# ラティアス
# 0
# ラティオス
# 0
# グラードン
# 0
# ドダイトス
# 0
# ムクバード
# 0
# ムクホーク
# 0
# レントラー
# 0
# ロズレイド
# 0
# ズガイドス
# 0
# ミノムッチ
# 0
# ミノマダム
# 0
# カラナクシ
# 0
# トリトドン
# 0
# フワライド
# 0
# ムウマージ
# 0
# ドンカラス
# 0
# ドーミラー
# 0
# ドータクン
# 0
# ドラピオン
# 0
# ドクロッグ
# 0
# マスキッパ
# 0
# ネオラント
# 0
# マニューラ
# 0
# ドサイドン
# 0
# グライオン
# 0
# エムリット
# 0
# ヒードラン
# 0
# ギラティナ
# 0
# ダークライ
# 0
# ['ラムパルド']
# ['ラムパルド']

# %%
import csv
from pokemon_search import pokemon_search

pokemon_name_5 = []
with open("pokemon_name_5.csv") as f:
    reader = csv.reader(f)
    for row in reader:
        pokemon_name_5 = row
print(pokemon_search(pokemon_name_5, "グラードン", "00102"))
# print(pokemon_search(["フシギダネ"], "グラードン", "00212"))
# Out:
# ['フーディン', 'サイホーン', 'バクフーン', 'アンノーン', 'ルナトーン', 'ビークイン', 'リーシャン', 'ブーバーン']

# %%
a = "アイウエオ"
b = "カキウケコ"
for i in range(5):
    print(a[i]  not in b)
# Out:
# True
# True
# False
# True
# True
